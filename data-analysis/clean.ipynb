# %%
import pandas as pd

# %% [markdown]
# ### Load the csv file

# %%
df = pd.read_csv('unclean_data.csv')
df.head(10)
# Out:
#          id  Locality Type of property Subtype of property   Price  \
# 0  20320744      1150        APARTMENT           APARTMENT  575000
# 1  20317718      9000        APARTMENT           APARTMENT  390000
# 2  20315842      9051        APARTMENT           APARTMENT  260000
# 3  20315799      9051        APARTMENT           APARTMENT  325000
# 4  20315776      9051        APARTMENT           APARTMENT  365000
# 5  20315874      9051        APARTMENT           APARTMENT  400000
# 6  20318337      1070        APARTMENT           PENTHOUSE  351500
# 7  20318338      1070        APARTMENT           PENTHOUSE  426500
# 8  20317581      9940        APARTMENT        GROUND_FLOOR  360000
# 9  20317589      9940        APARTMENT           PENTHOUSE  445000
#
#        Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 0  residential_sale                3        160.0                     1.0
# 1  residential_sale                3         96.0                     1.0
# ...

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ### remove duplicate

# %%
# check duplicates
df.duplicated().sum()
df
# Out:
#              id  Locality Type of property Subtype of property    Price  \
# 0      20320744      1150        APARTMENT           APARTMENT   575000
# 1      20317718      9000        APARTMENT           APARTMENT   390000
# 2      20315842      9051        APARTMENT           APARTMENT   260000
# 3      20315799      9051        APARTMENT           APARTMENT   325000
# 4      20315776      9051        APARTMENT           APARTMENT   365000
# ...         ...       ...              ...                 ...      ...
# 15511  10578089      8301        APARTMENT           APARTMENT  1495000
# 15512  20189566      8300        APARTMENT           APARTMENT  1195000
# 15513  20226843      2235            HOUSE               HOUSE   675000
# 15514  20199264      1150            HOUSE               HOUSE  1045000
# 15515  20312784      9040        APARTMENT           APARTMENT   435500
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# ...

# %%
#remove  duplicate rows based on the columns
df.drop_duplicates(inplace=True)
print(df)
# Out:
#              id  Locality Type of property Subtype of property    Price  \
# 0      20320744      1150        APARTMENT           APARTMENT   575000
# 1      20317718      9000        APARTMENT           APARTMENT   390000
# 2      20315842      9051        APARTMENT           APARTMENT   260000
# 3      20315799      9051        APARTMENT           APARTMENT   325000
# 4      20315776      9051        APARTMENT           APARTMENT   365000
# ...         ...       ...              ...                 ...      ...
# 15505  20020923      1000        APARTMENT           APARTMENT   455000
# 15506  20109298      8300        APARTMENT           APARTMENT   595000
# 15509  20280461      2100        APARTMENT           APARTMENT   249900
# 15514  20199264      1150            HOUSE               HOUSE  1045000
# 15515  20312784      9040        APARTMENT           APARTMENT   435500
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# ...

# %% [markdown]
# ### no blank space

# %% [markdown]
# remove any leading or trailing spaces from the column names in the DataFrame df

# %%
df.columns = df.columns.str.strip()
df.head()
# Out:
#          id  Locality Type of property Subtype of property   Price  \
# 0  20320744      1150        APARTMENT           APARTMENT  575000
# 1  20317718      9000        APARTMENT           APARTMENT  390000
# 2  20315842      9051        APARTMENT           APARTMENT  260000
# 3  20315799      9051        APARTMENT           APARTMENT  325000
# 4  20315776      9051        APARTMENT           APARTMENT  365000
#
#        Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 0  residential_sale                3        160.0                     1.0
# 1  residential_sale                3         96.0                     1.0
# 2  residential_sale                1         76.0                     1.0
# 3  residential_sale                1         81.0                     1.0
# 4  residential_sale                3        101.0                     1.0
#
#    Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# ...

# %%
#Drop empty columns
df.drop(columns=['Furnished','Fireplace'], inplace=True)

# %%
# display non empty columns
print(df.head())
# Out:
#          id  Locality Type of property Subtype of property   Price  \
# 0  20320744      1150        APARTMENT           APARTMENT  575000
# 1  20317718      9000        APARTMENT           APARTMENT  390000
# 2  20315842      9051        APARTMENT           APARTMENT  260000
# 3  20315799      9051        APARTMENT           APARTMENT  325000
# 4  20315776      9051        APARTMENT           APARTMENT  365000
#
#        Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 0  residential_sale                3        160.0                     1.0
# 1  residential_sale                3         96.0                     1.0
# 2  residential_sale                1         76.0                     1.0
# 3  residential_sale                1         81.0                     1.0
# 4  residential_sale                3        101.0                     1.0
#
#    Terrace  Terrace area  Garden  Garden area  Surface of the land  \
# ...

# %% [markdown]
# #### check missing value percentage

# %%
missing_percentage = df.isnull().mean() * 100
print(f"percentage of missing value per column: {missing_percentage}")
# Out:
# percentage of missing value per column: id                                   0.000000
# Locality                             0.000000
# Type of property                     0.000000
# Subtype of property                  0.000000
# Price                                0.000000
# Type of sale                         0.000000
# Number of rooms                      0.000000
# Living Area                          1.510920
# Fully equipped kitchen              29.473684
# Terrace                             22.649481
# Terrace area                        40.916577
# Garden                              80.379520
# Garden area                         80.379520
# Surface of the land                 80.379520
# Surface area of the plot of land    68.485499
# Number of facades                   34.729681
# Swimming pool                       62.993197
# State of the building               22.914429
# Compound Listing                     0.000000
# dtype: float64

# %% [markdown]
# ## no errors

# %%
# check missing values in each columns
missing_value=df.isnull().sum()
print("missing values in each columns \n", missing_value)
# Out:
# missing values in each columns
#  id                                      0
# Locality                                0
# Type of property                        0
# Subtype of property                     0
# Price                                   0
# Type of sale                            0
# Number of rooms                         0
# Living Area                           211
# Fully equipped kitchen               4116
# Terrace                              3163
# Terrace area                         5714
# Garden                              11225
# Garden area                         11225
# Surface of the land                 11225
# Surface area of the plot of land     9564
# Number of facades                    4850
# Swimming pool                        8797
# State of the building                3200
# Compound Listing                        0
# dtype: int64

# %% [markdown]
# ## fill missing values for numerical columns with mean(average)

# %%
# check data types of each columns 
df.dtypes

# fill missing values for all numerical values in our df
all_numerical_columns=df.select_dtypes(include=["float64","int64"]).columns
df[all_numerical_columns] = df[all_numerical_columns].fillna(df[all_numerical_columns].mean())

# check missing values
missing_value=df.isnull().sum()
print("missing values in each columns \n", missing_value)
# Out:
# missing values in each columns
#  id                                     0
# Locality                               0
# Type of property                       0
# Subtype of property                    0
# Price                                  0
# Type of sale                           0
# Number of rooms                        0
# Living Area                            0
# Fully equipped kitchen                 0
# Terrace                                0
# Terrace area                           0
# Garden                                 0
# Garden area                            0
# Surface of the land                    0
# Surface area of the plot of land       0
# Number of facades                      0
# Swimming pool                          0
# State of the building               3200
# Compound Listing                       0
# dtype: int64

# %%
# check data types of each columns 
df.dtypes

# fill missing values for all  categorical columns with mode or the most repetitive data
all_object_type_columns=df.select_dtypes(include=["object"]).columns
df[all_object_type_columns] = df[all_object_type_columns].fillna(df[all_object_type_columns].mode().iloc[0])

# check missing values
missing_value=df.isnull().sum()
print("missing values in each columns \n", missing_value)
# Out:
# missing values in each columns
#  id                                  0
# Locality                            0
# Type of property                    0
# Subtype of property                 0
# Price                               0
# Type of sale                        0
# Number of rooms                     0
# Living Area                         0
# Fully equipped kitchen              0
# Terrace                             0
# Terrace area                        0
# Garden                              0
# Garden area                         0
# Surface of the land                 0
# Surface area of the plot of land    0
# Number of facades                   0
# Swimming pool                       0
# State of the building               0
# Compound Listing                    0
# dtype: int64

# %% [markdown]
# ### save the cleaned data

# %%
print(df)
# save into csv file
cleaned_data= df.to_csv("../data_analysis/cleaned_data.csv",index=False)
# Out:
#              id  Locality Type of property Subtype of property    Price  \
# 0      20320744      1150        APARTMENT           APARTMENT   575000
# 1      20317718      9000        APARTMENT           APARTMENT   390000
# 2      20315842      9051        APARTMENT           APARTMENT   260000
# 3      20315799      9051        APARTMENT           APARTMENT   325000
# 4      20315776      9051        APARTMENT           APARTMENT   365000
# ...         ...       ...              ...                 ...      ...
# 15505  20020923      1000        APARTMENT           APARTMENT   455000
# 15506  20109298      8300        APARTMENT           APARTMENT   595000
# 15509  20280461      2100        APARTMENT           APARTMENT   249900
# 15514  20199264      1150            HOUSE               HOUSE  1045000
# 15515  20312784      9040        APARTMENT           APARTMENT   435500
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# ...
