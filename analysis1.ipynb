# %%
import pandas as pd

# %%
df = pd.read_csv('all_properties_data.csv')
df.head()
# Out:
#            ID  Postal_Code           Locality Type_of_property  \
# 0  20140691.0       1400.0           Nivelles            HOUSE
# 1  20288073.0       2000.0          Antwerpen        APARTMENT
# 2  20285251.0       8660.0           La Panne        APARTMENT
# 3  20238356.0       1050.0            Brussel            HOUSE
# 4  20290019.0       6900.0  Marche-en-Famenne            HOUSE
#
#   Subtype_of_property     Price   Type_of_sale  Number_of_rooms  Living_Area  \
# 0               VILLA  290000.0   Under_Option              5.0        123.0
# 1        GROUND_FLOOR  295000.0   Under_Option              1.0         55.0
# 2           APARTMENT  295000.0  Not specified              2.0         88.0
# 3               HOUSE  325000.0  Not specified              3.0        150.0
# 4               HOUSE  330000.0  Not specified              3.0        125.0
#
#   Fully_equipped_kitchen  ...  Open_fire  Terrace  Terrace_Area  Garden  \
# ...

# %%
df.dtypes
# Out:
# ID                        float64
# Postal_Code               float64
# Locality                   object
# Type_of_property           object
# Subtype_of_property        object
# Price                     float64
# Type_of_sale               object
# Number_of_rooms           float64
# Living_Area               float64
# Fully_equipped_kitchen     object
# Furnished                   int64
# Open_fire                   int64
# Terrace                     int64
# Terrace_Area              float64
# Garden                      int64
# Garden_Area               float64
# Surface_of_the_land       float64
# Number_of_facades         float64
# Swimming_pool               int64
# State_of_the_building      object
# Surface_area_plot_land    float64
# dtype: object

# %%
df.to_csv('df')
